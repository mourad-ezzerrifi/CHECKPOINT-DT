# %%
import pandas as pd 
import matplotlib.pyplot as plt
dataset=pd.read_csv("titanic-passengers.csv", sep=";")

#Preprocessing our data
def preprocess_data(new_data):
    new_data['Age'].fillna(new_data['Age'].mean(),inplace=True)
    new_data.replace({'Sex':{'male': 1,'female':0}},inplace=True)
    new_data['Cabin']=new_data.Cabin.fillna('G6')
    new_data.replace({'Survived':{'Yes': 1,'No':0}},inplace=True)
    return new_data
data=preprocess_data(dataset)

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
#features extraction
x=data.drop(["Survived", "Name", "Cabin", "Ticket", "Embarked"], axis=1)
y= data["Survived"]

#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

#applying tree algorithm
clf = DecisionTreeClassifier(max_depth=2, min_samples_leaf=50)  
clf.fit(x_train, y_train)   #fitting our model
y_pred=clf.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))

plt.figure(figsize=(21, 12))
tree_plot = tree.plot_tree(clf)
# Out:
# score:0.770949720670391

# %%
# dir(tree)
#Découvrir le module 'tree'

# %% [markdown]
# print("hello world")

# %%
clf = DecisionTreeClassifier(max_depth=3, min_samples_leaf=1)  
clf.fit(x_train, y_train)   #fitting our model
y_pred=clf.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))

plt.figure(figsize=(21, 12))
tree_plot = tree.plot_tree(clf)
# Out:
# score:0.8044692737430168

# %%
clf = RandomForestClassifier(n_estimators=22, max_depth=4, min_samples_leaf=1, random_state=12345)  
clf.fit(x_train, y_train)   #fitting our model
y_pred=clf.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.8379888268156425
